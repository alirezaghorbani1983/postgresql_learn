# %%
print(1)
# Out:
# 1

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\alirezaabadi\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (8.30.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (2.0.39)
# Requirement already satisfied: sqlparse in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\alirezaabadi\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\alirezaabadi\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alirezaabadi\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing in c:\users\alirezaabadi\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\alirezaabadi\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\alirezaabadi\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %% [markdown]
# ## connect to database

# %%
# %sql sqlite:///mydb.sqlite

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS users (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     username VARCHAR(50)
# );
#
# CREATE TABLE IF NOT EXISTS photos (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     url VARCHAR(200),
#     user_id INTEGER,
#     FOREIGN KEY (user_id) REFERENCES users(id)
# );
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# Done.
# []

# %%
# %%sql
#
#
# INSERT INTO users (username) VALUES
# ('monahan93'),
# ('pfeffer'),
# ('99stroman'),
# ('sim3onis');
#
# INSERT INTO photos (url, user_id) VALUES
# ('http://img1.jpg', 4),
# ('http://img2.jpg', 1),
# ('http://img3.jpg', 1),
# ('http://img4.jpg', 1),
# ('http://img5.jpg', 2),
# ('http://img6.jpg', 3),
# ('http://img7.jpg', 4);
# Out:
#  * sqlite:///mydb.sqlite
# 4 rows affected.
# 7 rows affected.
# []

# %%
# %%sql
# SELECT name FROM sqlite_master
# WHERE type ='table';
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT name FROM sqlite_master \nWHERE type ='table';\n\n")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %%
# %config SqlMagic.autopandas = False
# %config SqlMagic.style = 'PLAIN_COLUMNS'   # یا مثلاً 'DEFAULT'

# %%
# %%sql
# SELECT name FROM sqlite_master
# WHERE type='table';
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT name FROM sqlite_master\nWHERE type='table';\n")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'PLAIN_COLUMNS'

# %%
# %config SqlMagic.style
# Out:
# 'PLAIN_COLUMNS'

# %%
# %config SqlMagic.style = None
# Out:
# ERROR:root:The 'style' trait of a SqlMagic instance expected a unicode string, not the NoneType None.

# %%
# %config SqlMagic.style = 'PLAIN'

# %%
# %config SqlMagic
# Out:
# SqlMagic(Magics, Configurable) options
# ------------------------------------
# SqlMagic.autocommit=<Bool>
#     Set autocommit mode
#     Current: True
# SqlMagic.autolimit=<Int>
#     Automatically limit the size of the returned result sets
#     Current: 0
# SqlMagic.autopandas=<Bool>
#     Return Pandas DataFrames instead of regular result sets
#     Current: False
# SqlMagic.column_local_vars=<Bool>
#     Return data into local variables from column names
#     Current: False
# SqlMagic.displaycon=<Bool>
#     Show connection string after execute
#     Current: True
# SqlMagic.displaylimit=<Int>
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
#     Current: None
# SqlMagic.dsn_filename=<Unicode>
#     Path to DSN file. When the first argument is of the form [section], a
#     sqlalchemy connection string is formed from the matching section in the DSN
#     file.
#     Current: 'odbc.ini'
# SqlMagic.feedback=<Bool>
#     Print number of rows affected by DML
#     Current: True
# SqlMagic.short_errors=<Bool>
#     Don't display the full traceback on SQL Programming Error
#     Current: True
# SqlMagic.style=<Unicode>
#     Set the table printing style to any of prettytable's defined styles
#     (currently DEFAULT, MSWORD_FRIENDLY, PLAIN_COLUMNS, RANDOM)
#     Current: 'PLAIN'

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT name FROM sqlite_master WHERE type='table';\n")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'PLAIN'

# %%
# %sql sqlite:///mydb.sqlite

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///mydb.sqlite

# %%
# %%sql
# SELECT 1;
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT 1;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'PLAIN'

# %%
# %config SqlMagic.style = 'DEFAULT'

# %%
# %config SqlMagic.style
# Out:
# 'DEFAULT'

# %%
# %%sql
# SELECT 1;
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT 1;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %%
# %load_ext sql
# %config SqlMagic.style = 'DEFAULT'
# %sql sqlite:///mydb.sqlite
# %%sql
SELECT 1;
# Out:
#   Cell In[1], line 5
#     SELECT 1;
#            ^
# SyntaxError: invalid syntax

# %%
# %load_ext sql
# %config SqlMagic.style = 'DEFAULT'

# %%
# %sql sqlite:///mydb.sqlite

# %%
# %%sql
# SELECT 1;
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT 1;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:374, in run(conn, sql, config, user_namespace)
#     372     if result and config.feedback:
#     373         print(interpret_rowcount(result.rowcount))
# --> 374 resultset = ResultSet(result, config)
#     375 if config.autopandas:
#     376     return resultset.DataFrame()
#
# File ~\anaconda3\Lib\site-packages\sql\run.py:116, in ResultSet.__init__(self, sqlaproxy, config)
#     114         list.__init__(self, sqlaproxy.fetchall())
#     115     self.field_names = unduplicate_field_names(self.keys)
# --> 116     self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117 else:
#     118     list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///mydb.sqlite

# %%
# %%sql
# SELECT 1;
# Out:
#  * sqlite:///mydb.sqlite
# Done.
# [(1,)]
